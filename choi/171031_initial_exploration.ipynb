# %%
pd.options.display.max_columns = 400

# %% [markdown]
# # Red Hat

# %%
df_ppl = pd.read_csv('../__data/people.csv')
df_ppl.head(10)
# Out:
#     people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0     ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1  ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2  ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3  ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4  ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
# 5   ppl_10001  type 2  group 25417  type 3  2022-10-14   type 6   type 6
# 6  ppl_100010  type 2  group 17304  type 2  2022-09-01   type 8   type 7
# 7  ppl_100013  type 2   group 4204  type 3  2023-01-24   type 4   type 8
# 8  ppl_100019  type 2  group 45749  type 3  2023-03-26  type 40  type 25
# 9  ppl_100025  type 2  group 36096  type 3  2022-08-26  type 14   type 6
#
#    char_5  char_6   char_7  char_8  char_9  char_10  char_11  char_12  \
# 0  type 5  type 3  type 11  type 2  type 2     True    False    False
# ...

# %%
df_ppl.columns
# Out:
# Index(['people_id', 'char_1', 'group_1', 'char_2', 'date', 'char_3', 'char_4',
#        'char_5', 'char_6', 'char_7', 'char_8', 'char_9', 'char_10', 'char_11',
#        'char_12', 'char_13', 'char_14', 'char_15', 'char_16', 'char_17',
#        'char_18', 'char_19', 'char_20', 'char_21', 'char_22', 'char_23',
#        'char_24', 'char_25', 'char_26', 'char_27', 'char_28', 'char_29',
#        'char_30', 'char_31', 'char_32', 'char_33', 'char_34', 'char_35',
#        'char_36', 'char_37', 'char_38'],
#       dtype='object')

# %%
df_ppl.shape
# Out:
# (189118, 41)

# %%
df_train = pd.read_csv('../__data/act_train.csv')
df_train.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
df_train.columns
# Out:
# Index(['people_id', 'activity_id', 'date', 'activity_category', 'char_1',
#        'char_2', 'char_3', 'char_4', 'char_5', 'char_6', 'char_7', 'char_8',
#        'char_9', 'char_10', 'outcome'],
#       dtype='object')

# %%
df_train.shape
# Out:
# (2197291, 15)

# %%
df_train.loc[df_train['people_id'].isin(df_train['people_id'].value_counts().head().index), :].head()
# Out:
#         people_id   activity_id        date activity_category char_1 char_2  \
# 33366  ppl_105739  act2_1000030  2022-09-30            type 3    NaN    NaN
# 33367  ppl_105739  act2_1000149  2022-09-30            type 3    NaN    NaN
# 33368  ppl_105739  act2_1000258  2022-09-29            type 3    NaN    NaN
# 33369  ppl_105739  act2_1000275  2022-09-28            type 3    NaN    NaN
# 33370  ppl_105739   act2_100029  2022-09-28            type 3    NaN    NaN
#
#       char_3 char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 33366    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 23        0
# 33367    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 23        0
# 33368    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 23        0
# 33369    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 23        0
# 33370    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 23        0

# %%
df_train['outcome'].value_counts()
# Out:
# 0    1221794
# 1     975497
# Name: outcome, dtype: int64

# %%
# %%time
df_trainm = df_ppl.merge(df_train, on='people_id', suffixes=('_ppl', '_act'))
# Out:
# Wall time: 1.12 s

# %%
df_trainm.head()
# Out:
#   people_id char_1_ppl      group_1 char_2_ppl    date_ppl char_3_ppl  \
# 0   ppl_100     type 2  group 17304     type 2  2021-06-29     type 5
# 1   ppl_100     type 2  group 17304     type 2  2021-06-29     type 5
# 2   ppl_100     type 2  group 17304     type 2  2021-06-29     type 5
# 3   ppl_100     type 2  group 17304     type 2  2021-06-29     type 5
# 4   ppl_100     type 2  group 17304     type 2  2021-06-29     type 5
#
#   char_4_ppl char_5_ppl char_6_ppl char_7_ppl char_8_ppl char_9_ppl  \
# 0     type 5     type 5     type 3    type 11     type 2     type 2
# 1     type 5     type 5     type 3    type 11     type 2     type 2
# 2     type 5     type 5     type 3    type 11     type 2     type 2
# 3     type 5     type 5     type 3    type 11     type 2     type 2
# 4     type 5     type 5     type 3    type 11     type 2     type 2
#
#    char_10_ppl  char_11  char_12  char_13  char_14  char_15  char_16  char_17  \
# ...
